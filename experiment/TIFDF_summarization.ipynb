# %%
from pprint import pprint
from datasets import load_dataset
from transformers import AutoTokenizer
tokenizer = AutoTokenizer.from_pretrained('distilbert-base-uncased')
from torch.utils.data import DataLoader
import nltk
import os
import re
import math
import operator
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
from nltk.tokenize import sent_tokenize,word_tokenize
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/rei/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to /Users/rei/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to /Users/rei/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/rei/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
hupd_dict = load_dataset('HUPD/hupd',
    name='sample',
    data_files="https://huggingface.co/datasets/HUPD/hupd/blob/main/hupd_metadata_2022-02-22.feather",
    icpr_label=None,
    train_filing_start_date='2016-01-01',
    train_filing_end_date='2016-01-25',
    val_filing_start_date='2016-01-26',
    val_filing_end_date='2016-01-31',
)

# %%
Stopwords = set(stopwords.words('english'))
wordlemmatizer = WordNetLemmatizer()

# %%
dirty_claim = hupd_dict['train'][4]['claims']

# %%
dirty_claim
# Out:
# '1. A crystal growth furnace for growing a crystalline ingot comprising: a crucible containing at least feedstock material; and a liquid-cooled heat exchanger that is vertically movable beneath the crucible comprising: a heat extraction bulb made of a material having a thermal conductivity value of greater than about 200 W/(m·k); and a liquid coolant inlet tube and a liquid coolant outlet tube, wherein the liquid coolant inlet tube, the liquid coolant outlet tube, or both are attached to the heat extraction bulb for circulating a liquid coolant therethrough. 2. The crystal growth furnace of claim 1, wherein the liquid coolant comprises water. 3. The crystal growth furnace of claim 1, wherein the material has a melting point less than a melting point of the feedstock. 4. The crystal growth furnace of claim 3, wherein the melting point of the feedstock and the melting point of the material differ by not more than about 455° C. 5. The crystal growth furnace of claim 3, wherein the melting point of the feedstock and the melting point of the material differ by not more than about 330° C. 6. The crystal growth furnace of claim 1, wherein the material comprises copper, silver or gold. 7. The crystal growth furnace of claim 1, wherein the heat extraction bulb has an internal cavity to receive the liquid coolant from the liquid coolant inlet tube and discharge the liquid coolant through the liquid coolant outlet tube. 8. The crystal growth furnace of claim 7, wherein the internal cavity is bulbous in shape. 9. The crystal growth furnace of claim 1, wherein the liquid coolant inlet tube and liquid coolant outlet tube are coaxial. 10. The crystal growth furnace of claim 9, wherein the liquid coolant inlet tube is inside the liquid coolant outlet tube. 11. The crystal growth furnace of claim 9, wherein the liquid coolant outlet tube is inside the liquid coolant inlet tube. 12. The crystal growth furnace of claim 1, wherein the liquid coolant inlet tube and liquid coolant outlet tube are enclosed in an insulation sheath within the furnace. 13. The crystal growth furnace of claim 12, wherein the insulation sheath is made of graphite or alumina. 14. The crystal growth furnace of claim 1, wherein the liquid-cooled heat exchanger is vertically movable into thermal contact with the crucible. 15. The crystal growth furnace of claim 1, wherein the crucible sits atop a crucible support and the liquid-cooled heat exchanger is vertically movable into thermal contact with the crucible support. 16. The crystal growth furnace of claim 15, wherein the crucible support comprises an opening that is sized and shaped to receive the heat extraction bulb and the heat extraction bulb is vertically movable into the opening. 17. The crystal growth furnace of claim 1, wherein the crucible sits in a crucible box atop a crucible support and the liquid-cooled heat exchanger is vertically movable into thermal contact with the crucible support. 18. The crystal growth furnace of claim 17, wherein the crucible support comprises an opening that is sized and shaped to receive the heat extraction bulb and the heat extraction bulb is vertically movable into the opening. 19. The crystal growth furnace of claim 1, wherein the liquid-cooled heat exchanger is in a sealed tubular outer jacket. 20. The crystal growth furnace of claim 19, wherein the liquid-cooled heat exchanger is vertically movable within the sealed tubular outer jacket into thermal communication with the crucible. 21. The crystal growth furnace of claim 19, wherein the crucible sits atop a crucible support and the liquid-cooled heat exchanger is vertically movable within the sealed tubular outer jacket into thermal communication with the crucible support. 22. The crystal growth furnace of claim 21, wherein the crucible support comprises an opening that is sized and shaped to receive the sealed tubular outer jacket. 23. The crystal growth furnace of claim 19, wherein the crucible sits in a crucible box atop a cr ...

# %% [markdown]
# ## Sentence Tokenization V2

# %%
import re

def process_claims_v10(dirty_claim):
    # Split the claims on each claim number or range of claim numbers
    split_claims = re.split(r'(?<=\.\s)(\d+-*\d*\.\s)', dirty_claim)

    combined_sentences = []
    current_claim = ""

    for part in split_claims:
        if re.match(r'\d+-*\d*\.\s', part):
            # If current_claim is not empty, add it to combined_sentences
            if current_claim:
                combined_sentences.append(current_claim.strip())
            current_claim = part
        else:
            current_claim += part

    # Add the last claim
    if current_claim:
        combined_sentences.append(current_claim.strip())

    # Handle ranges of canceled claims and keep the subsequent claims
    processed_claims = []
    for claim in combined_sentences:
        # Remove the '(canceled)' phrase
        claim = re.sub(r'\(canceled\)', '', claim)

        # Remove claim numbers
        claim = re.sub(r'\b\d+-*\d*\.\s*', '', claim)

        processed_claims.append(claim)

    return processed_claims


combined_sentences_v10 = process_claims_v10(dirty_claim)

for index, sentence in enumerate(combined_sentences_v10):
    print(f"Claim {index+1}: {sentence}")
# Out:
# Claim 1: A crystal growth furnace for growing a crystalline ingot comprising: a crucible containing at least feedstock material; and a liquid-cooled heat exchanger that is vertically movable beneath the crucible comprising: a heat extraction bulb made of a material having a thermal conductivity value of greater than about 200 W/(m·k); and a liquid coolant inlet tube and a liquid coolant outlet tube, wherein the liquid coolant inlet tube, the liquid coolant outlet tube, or both are attached to the heat extraction bulb for circulating a liquid coolant therethrough.
# Claim 2: The crystal growth furnace of claim 1, wherein the liquid coolant comprises water.
# Claim 3: The crystal growth furnace of claim 1, wherein the material has a melting point less than a melting point of the feedstock.
# Claim 4: The crystal growth furnace of claim 3, wherein the melting point of the feedstock and the melting point of the material differ by not more than about 455° C.
# Claim 5: The crystal growth furnace of claim 3, wherein the melting point of the feedstock and the melting point of the material differ by not more than about 330° C.
# Claim 6: The crystal growth furnace of claim 1, wherein the material comprises copper, silver or gold.
# Claim 7: The crystal growth furnace of claim 1, wherein the heat extraction bulb has an internal cavity to receive the liquid coolant from the liquid coolant inlet tube and discharge the liquid coolant through the liquid coolant outlet tube.
# Claim 8: The crystal growth furnace of claim 7, wherein the internal cavity is bulbous in shape.
# Claim 9: The crystal growth furnace of claim 1, wherein the liquid coolant inlet tube and liquid coolant outlet tube are coaxial.
# Claim 10: The crystal growth furnace of claim 9, wherein the liquid coolant inlet tube is inside the liquid coolant outlet tube.
# Claim 11: The crystal growth furnace of claim 9, wherein the liquid coolant outlet tube is inside the liquid coolant inlet tube.
# Claim 12: The crystal growth furnace of claim 1, wherein the liquid coolant inlet tube and liquid coolant outlet tube are enclosed in an insulation sheath within the furnace.
# Claim 13: The crystal growth furnace of claim 12, wherein the insulation sheath is made of graphite or alumina.
# Claim 14: The crystal growth furnace of claim 1, wherein the liquid-cooled heat exchanger is vertically movable into thermal contact with the crucible.
# Claim 15: The crystal growth furnace of claim 1, wherein the crucible sits atop a crucible support and the liquid-cooled heat exchanger is vertically movable into thermal contact with the crucible support.
# Claim 16: The crystal growth furnace of claim 15, wherein the crucible support comprises an opening that is sized and shaped to receive the heat extraction bulb and the heat extraction bulb is vertically movable into the opening.
# Claim 17: The crystal growth furnace of claim 1, wherein the crucible sits in a crucible box atop a crucible support and the liquid-cooled heat exchanger is vertically movable into thermal contact with the crucible support.
# Claim 18: The crystal growth furnace of claim 17, wherein the crucible support comprises an opening that is sized and shaped to receive the heat extraction bulb and the heat extraction bulb is vertically movable into the opening.
# Claim 19: The crystal growth furnace of claim 1, wherein the liquid-cooled heat exchanger is in a sealed tubular outer jacket.
# Claim 20: The crystal growth furnace of claim 19, wherein the liquid-cooled heat exchanger is vertically movable within the sealed tubular outer jacket into thermal communication with the crucible.
# Claim 21: The crystal growth furnace of claim 19, wherein the crucible sits atop a crucible support and the liquid-cooled heat exchanger is vertically movable within the sealed tubular outer jacket into thermal communication with the crucible support.
# Claim 22: The crystal growth furnace of claim 21, wherein the crucible support comprises an opening that is sized and shaped to receive the sealed tubular outer jacket.
# Claim 23: The crystal growth furnace of claim 19, wherein the crucible sits in a crucible box atop a crucible support and the liquid-cooled heat exchanger is vertically movable within the sealed tubular outer jacket into thermal communication with the crucible support.
# Claim 24: The crystal growth furnace of claim 23, wherein the crucible support comprises an opening that is sized and shaped to receive the sealed tubular outer jacket.
# Claim 25: The crystal growth furnace of claim 19, wherein the sealed tubular outer jacket comprises molybdenum or graphite.
# Claim 26: The crystal growth furnace of claim 19, wherein the sealed tubular outer jacket comprises a vacuum inlet port, an inert gas injection port and an over-pressure release valve outside the crystal growth furnace.
# Claim 27: The crystal growth furnace of claim 19, wherein the sealed tubular outer jacket further comprises an inert gas.
# Claim 28: The crystal growth furnace of claim 19, wherein the sealed tubular outer jacket is stationary.
# Claim 29: The crystal growth furnace of claim 19, wherein the sealed tubular outer jacket is vertically movable.
# Claim 30: The crystal growth furnace of claim 19, wherein the sealed tubular outer jacket is a crucible support shaft.
# Claim 31: The crystal growth furnace of claim 1, wherein the feedstock material comprises polycrystalline silicon.
# Claim 32: The crystal growth furnace of claim 1, wherein the crystalline ingot is silicon.
# Claim 33: A liquid-cooled heat exchanger, wherein: the liquid-cooled heat exchanger comprises a heat extraction bulb made of a material having a thermal conductivity value of greater than about 200 W/(m·k) and a liquid coolant inlet tube and a liquid coolant outlet tube wherein the liquid coolant inlet tube, the liquid coolant outlet tube, or both are attached to the heat extraction bulb for circulating a liquid coolant therethrough, and wherein the liquid-cooled heat exchanger is vertically movable.
# Claim 34: The liquid-cooled heat exchanger of claim 33, wherein the liquid-cooled heat exchanger is in a sealed tubular outer jacket.
# Claim 35: A method for producing a crystalline ingot in a crystal growth furnace, comprising the steps of: placing a crucible having at least feedstock material in the crystal growth furnace; circulating a liquid coolant through a liquid-cooled heat exchanger that is vertically movable beneath the crucible, wherein the liquid-cooled heat exchanger comprises a heat extraction bulb made of a material having a thermal conductivity value of greater than about 200 W/(m·k), a liquid coolant inlet tube and a liquid coolant outlet tube, wherein the liquid coolant inlet tube, the liquid coolant outlet tube, or both are attached to the heat extraction bulb for circulating the liquid coolant therethrough; heating and melting the at least feedstock material in the crucible; and vertically moving the liquid-cooled heat exchanger into thermal communication with the crucible in order to promote the growth of the crystalline ingot.
# Claim 36: The method of claim 35, wherein vertically moving the liquid-cooled heat exchanger is controlled by feedback obtained by monitoring the melting of the at least feedback material.
# Claim 37: The method of claim 35, wherein the liquid-cooled heat exchanger is enclosed in a sealed tubular outer jacket, and wherein the method further comprises the steps of evacuating the sealed tubular outer jacket and backfilling with inert gas before the step of heating and melting the at least feedstock in the crucible.
# Claim 38: The method of claim 35, wherein inert gas is backfilled to at least about 5-15 psig.

# %% [markdown]
# ---

# %% [markdown]
# ## TFIDF Summarization

# %% [markdown]
# ### <strong> [TFIDF] readymade extractive summarization

# %%
def lemmatize_words(words):
    lemmatized_words = []
    for word in words:
       lemmatized_words.append(wordlemmatizer.lemmatize(word))
    return lemmatized_words
def stem_words(words):
    stemmed_words = []
    for word in words:
       stemmed_words.append(stemmer.stem(word))
    return stemmed_words
def remove_special_characters(text):
    regex = r'[^a-zA-Z0-9\s]'
    text = re.sub(regex,'',text)
    return text
def freq(words):
    words = [word.lower() for word in words]
    dict_freq = {}
    words_unique = []
    for word in words:
       if word not in words_unique:
           words_unique.append(word)
    for word in words_unique:
       dict_freq[word] = words.count(word)
    return dict_freq
def pos_tagging(text):
    pos_tag = nltk.pos_tag(text.split())
    pos_tagged_noun_verb = []
    for word,tag in pos_tag:
        if tag == "NN" or tag == "NNP" or tag == "NNS" or tag == "VB" or tag == "VBD" or tag == "VBG" or tag == "VBN" or tag == "VBP" or tag == "VBZ":
             pos_tagged_noun_verb.append(word)
    return pos_tagged_noun_verb
def tf_score(word,sentence):
    freq_sum = 0
    word_frequency_in_sentence = 0
    len_sentence = len(sentence)
    for word_in_sentence in sentence.split():
        if word == word_in_sentence:
            word_frequency_in_sentence = word_frequency_in_sentence + 1
    tf =  word_frequency_in_sentence/ len_sentence
    return tf
def idf_score(no_of_sentences,word,sentences):
    no_of_sentence_containing_word = 0
    for sentence in sentences:
        sentence = remove_special_characters(str(sentence))
        sentence = re.sub(r'\d+', '', sentence)
        sentence = sentence.split()
        sentence = [word for word in sentence if word.lower() not in Stopwords and len(word)>1]
        sentence = [word.lower() for word in sentence]
        sentence = [wordlemmatizer.lemmatize(word) for word in sentence]
        if word in sentence:
            no_of_sentence_containing_word = no_of_sentence_containing_word + 1
    idf = math.log10(no_of_sentences/no_of_sentence_containing_word)
    return idf
def tf_idf_score(tf,idf):
    return tf*idf
def word_tfidf(dict_freq,word,sentences,sentence):
    word_tfidf = []
    tf = tf_score(word,sentence)
    idf = idf_score(len(sentences),word,sentences)
    tf_idf = tf_idf_score(tf,idf)
    return tf_idf
def sentence_importance(sentence,dict_freq,sentences):
     sentence_score = 0
     sentence = remove_special_characters(str(sentence)) 
     sentence = re.sub(r'\d+', '', sentence)
     pos_tagged_sentence = [] 
     no_of_sentences = len(sentences)
     pos_tagged_sentence = pos_tagging(sentence)
     for word in pos_tagged_sentence:
          if word.lower() not in Stopwords and word not in Stopwords and len(word)>1: 
                word = word.lower()
                word = wordlemmatizer.lemmatize(word)
                sentence_score = sentence_score + word_tfidf(dict_freq,word,sentences,sentence)
     return sentence_score

# %%
# tokenized_sentence = sent_tokenize(dirty_claim)
text = remove_special_characters(str(dirty_claim))
text = re.sub(r'\d+', '', dirty_claim)
tokenized_words_with_stopwords = word_tokenize(dirty_claim)
tokenized_words = [word for word in tokenized_words_with_stopwords if word not in Stopwords]
tokenized_words = [word for word in tokenized_words if len(word) > 1]
tokenized_words = [word.lower() for word in tokenized_words]
tokenized_words = lemmatize_words(tokenized_words)
word_freq = freq(tokenized_words)
input_user = int(input('Percentage of information to retain(in percent):'))
no_of_sentences = int((input_user * len(combined_sentences_v10))/100)
print(no_of_sentences)
c = 1
sentence_with_importance = {}
for sent in combined_sentences_v10:
    sentenceimp = sentence_importance(sent,word_freq,combined_sentences_v10)
    sentence_with_importance[c] = sentenceimp
    c = c+1
sentence_with_importance = sorted(sentence_with_importance.items(), key=operator.itemgetter(1),reverse=True)
cnt = 0
summary = []
sentence_no = []
for word_prob in sentence_with_importance:
    if cnt < no_of_sentences:
        sentence_no.append(word_prob[0])
        cnt = cnt+1
    else:
      break
sentence_no.sort()
cnt = 1
for sentence in combined_sentences_v10:
    if cnt in sentence_no:
       summary.append(sentence)
    cnt = cnt+1
readymade_summary = " ".join(summary)
print("\n")
print("Summary:")
print(readymade_summary)
# outF = open('summary.txt',"w")
# outF.write(summary)
# Out:
# 11
#
#
# Summary:
# A crystal growth furnace for growing a crystalline ingot comprising: a crucible containing at least feedstock material; and a liquid-cooled heat exchanger that is vertically movable beneath the crucible comprising: a heat extraction bulb made of a material having a thermal conductivity value of greater than about 200 W/(m·k); and a liquid coolant inlet tube and a liquid coolant outlet tube, wherein the liquid coolant inlet tube, the liquid coolant outlet tube, or both are attached to the heat extraction bulb for circulating a liquid coolant therethrough. The crystal growth furnace of claim 3, wherein the melting point of the feedstock and the melting point of the material differ by not more than about 455° C. The crystal growth furnace of claim 1, wherein the heat extraction bulb has an internal cavity to receive the liquid coolant from the liquid coolant inlet tube and discharge the liquid coolant through the liquid coolant outlet tube. The crystal growth furnace of claim 1, wherein the liquid coolant inlet tube and liquid coolant outlet tube are enclosed in an insulation sheath within the furnace. The crystal growth furnace of claim 15, wherein the crucible support comprises an opening that is sized and shaped to receive the heat extraction bulb and the heat extraction bulb is vertically movable into the opening. The crystal growth furnace of claim 17, wherein the crucible support comprises an opening that is sized and shaped to receive the heat extraction bulb and the heat extraction bulb is vertically movable into the opening. The crystal growth furnace of claim 19, wherein the sealed tubular outer jacket comprises a vacuum inlet port, an inert gas injection port and an over-pressure release valve outside the crystal growth furnace. A liquid-cooled heat exchanger, wherein: the liquid-cooled heat exchanger comprises a heat extraction bulb made of a material having a thermal conductivity value of greater than about 200 W/(m·k) and a liquid coolant inlet tube and a liquid coolant outlet tube wherein the liquid coolant inlet tube, the liquid coolant outlet tube, or both are attached to the heat extraction bulb for circulating a liquid coolant therethrough, and wherein the liquid-cooled heat exchanger is vertically movable. A method for producing a crystalline ingot in a crystal growth furnace, comprising the steps of: placing a crucible having at least feedstock material in the crystal growth furnace; circulating a liquid coolant through a liquid-cooled heat exchanger that is vertically movable beneath the crucible, wherein the liquid-cooled heat exchanger comprises a heat extraction bulb made of a material having a thermal conductivity value of greater than about 200 W/(m·k), a liquid coolant inlet tube and a liquid coolant outlet tube, wherein the liquid coolant inlet tube, the liquid coolant outlet tube, or both are attached to the heat extraction bulb for circulating the liquid coolant therethrough; heating and melting the at least feedstock material in the crucible; and vertically moving the liquid-cooled heat exchanger into thermal communication with the crucible in order to promote the growth of the crystalline ingot. The method of claim 35, wherein vertically moving the liquid-cooled heat exchanger is controlled by feedback obtained by monitoring the melting of the at least feedback material. The method of claim 35, wherein inert gas is backfilled to at least about 5-15 psig.

# %% [markdown]
# ---

# %% [markdown]
# ### <strong> [TF-IDF] Maths only calculation

# %% [markdown]
# reference from : https://towardsdatascience.com/text-summarization-using-tf-idf-e64a0644ace3

# %% [markdown]
# Background
#
# TF-IDF is made up of two algorithms:
# - Term Frequency : how common a word is
#     - calculation: </br>
#     <code> TF(t) = (Number of times term t appears in a document) / (Total number of terms in the document) </code>
# - Inverse Document Frequency : how unique a word is
#     - calculation: </br>
#         <code> IDF(t) = log_e(Total number of documents / Number of documents with term t in it) </code>

# %% [markdown]
# ### TF Calculation

# %% [markdown]
# <strong>Frequency Matrix Calcuation </strong> </br>
# - An empty dictionary called <code> frequency_matrix</code> is created to store the frequency of the words
# - <strong> Stopwords & PorterStemmer  </strong> is used to remove the stopwords and stemming the words.
# - each sentence is being tokenized into word level and count the tokens and put in the freq_table to store the frequencies of the word.
# - Each words are converted into lowercase and then stemmed. stopwords are being ignored in this step. For each word, this block checks if it's already in the freq_table.
# - If it is, the frequency count is incremented.
# - If not, the word is added to the table with a frequency count of 1.
# - The frequency table for each sentence is added to the frequency_matrix with a key. The key is the length of the sentence for now

# %%
from nltk.stem import PorterStemmer

def _create_frequency_matrix(sentences):
    frequency_matrix = {}
    stopWords = set(stopwords.words("english"))
    ps = PorterStemmer()

    for sent in sentences:
        freq_table = {}
        words = word_tokenize(sent)
        for word in words:
            word = word.lower()
            word = ps.stem(word)
            if word in stopWords:
                continue

            if word in freq_table:
                freq_table[word] += 1
            else:
                freq_table[word] = 1

        frequency_matrix[sent[:200]] = freq_table

    return frequency_matrix

freq_matrix = _create_frequency_matrix(combined_sentences_v10)
freq_matrix
# Out:
# {'A heat shield for shielding hot areas of a combustion engine comprising at least one metal sheet layer with a first and a second surface, with the at least one metal sheet layer comprising at least on': {'heat': 1,
#   'shield': 2,
#   'hot': 1,
#   'area': 8,
#   'combust': 1,
#   'engin': 1,
#   'compris': 3,
#   'least': 5,
#   'one': 3,
#   'metal': 2,
#   'sheet': 2,
#   'layer': 2,
#   'first': 7,
#   'second': 3,
#   'surfac': 3,
#   ',': 13,
#   'passag': 11,
#   'open': 10,
#   'fasten': 1,
#   'element': 4,
#   'sleev': 5,
#   'pass': 1,
#   'wherein': 1,
#   'decoupl': 3,
#   'flexibl': 1,
#   'materi': 1,
#   'arrang': 1,
#   'circumferenti': 3,
#   'edg': 3,
#   ';': 1,
#   ')': 3,
#   'annular': 1,
#   'shank': 4,
#   'penetr': 1,
#   'b': 1,
#   'collar': 6,
#   'extend': 4,
#   'radial': 5,
#   'outward': 2,
#   'rel': 3,
#   'c': 1,
#   'adjac': 1,
#   'region': 3,
#   'show': 2,
#   'constant': 1,
#   'wall': 2,
#   'thick': 2,
#   'transit': 2,
#   'section': 2,
#   'outwardli': 1,
#   'increas': 1,
#   'round': 1,
#   'inclin': 1,
#   '.': 1},
#  'The heat shield according to claim 18, wherein at least one of said sections of said transition area shows an increased radial wall thickness, each of these transition areas shows an increased radial ': {'heat': 1,
#   'shield': 1,
#   'accord': 1,
#   'claim': 1,
#   '18': 1,
#   ',': 3,
#   'wherein': 1,
#   'least': 1,
#   'one': 1,
#   'said': 2,
#   'section': 4,
#   'transit': 3,
#   'area': 4,
#   'show': 2,
#   'increas': 2,
#   'radial': 2,
#   'wall': 3,
#   'thick': 3,
#   'compar': 1,
#   'respect': 2,
#   'shank': 2,
#   'region': 1,
#   'passag': 1,
#   'open': 1,
#   'locat': 1,
#   'circular': 1,
#   'segment': 1,
#   'sleev': 1,
#   '.': 1},
#  'The heat shield according to claim 18, wherein the transition area between the shank area and the first collar of the sleeve on at least 90% of its circumferential extension shows a distance to the me': {'heat': 1,
#   'shield': 1,
#   'accord': 1,
#   'claim': 1,
#   '18': 1,
#   ',': 2,
#   'wherein': 1,
#   'transit': 1,
#   'area': 4,
#   'shank': 2,
#   'first': 1,
#   'collar': 1,
#   'sleev': 2,
#   'least': 1,
#   '90': 1,
#   '%': 1,
#   'circumferenti': 1,
#   'extens': 1,
#   'show': 1,
#   'distanc': 1,
#   'metal': 1,
#   'sheet': 1,
#   'layer': 1,
#   'larger': 1,
#   'materi': 1,
#   'thick': 1,
#   'passag': 1,
#   'open': 1,
#   '.': 1},
#  'The heat shield according to claim 18, wherein the transition area between the shank area and the first collar of the sleeve on at least 90% of its radial extension shows a radial curvature radius whi': {'heat': 1,
#   'shield': 1,
#   'accord': 1,
#   'claim': 1,
#   '18': 1,
#   ',': 1,
#   'wherein': 1,
#   'transit': 1,
#   'area': 4,
#   'shank': 2,
#   'first': 1,
#   'collar': 1,
#   'sleev': 2,
#   'least': 1,
#   '90': 1,
#   '%': 1,
#   'radial': 2,
#   'extens': 1,
#   'show': 1,
#   'curvatur': 1,
#   'radiu': 1,
#   'larger': 1,
#   'materi': 1,
#   'thick': 1,
#   'passag': 1,
#   'open': 1,
#   '.': 1},
#  'The heat shield according to claim 18, wherein the decoupling element in the area of its second collar comprises an inner diameter (Di12) which is larger than the inner diameter (Di13) in the area of ': {'heat': 1,
#   'shield': 1,
#   'accord': 1,
#   'claim': 1,
#   '18': 1,
#   ',': 1,
#   'wherein': 1,
#   'decoupl': 1,
#   'element': 1,
#   'area': 2,
#   'second': 1,
#   'collar': 1,
#   'compris': 1,
#   'inner': 2,
#   'diamet': 2,
#   '(': 2,
#   'di12': 1,
#   ')': 2,
#   'larger': 1,
#   'di13': 1,
#   'passag': 1,
#   'open': 1,
#   '.': 1},
#  'The heat shield according to claim 18, wherein the decoupling element is composed of metal wire mesh or silicone.': {'heat': 1,
#   'shield': 1,
#   'accord': 1,
#   'claim': 1,
#   '18': 1,
#   ',': 1,
#   'wherein': 1,
#   'decoupl': 1,
#   'element': 1,
#   'compos': 1,
#   'metal': 1,
#   'wire': 1,
#   'mesh': 1,
#   'silicon': 1,
#   '.': 1},
#  'The heat shield according to claim 18, wherein the first collar of the decoupling element is radially formed towards an outside between the metal sheet layer and the first collar of the sleeve.': {'heat': 1,
#   'shield': 1,
#   'accord': 1,
#   'claim': 1,
#   '18': 1,
#   ',': 1,
#   'wherein': 1,
#   'first': 2,
#   'collar': 2,
#   'decoupl': 1,
#   'element': 1,
#   'radial': 1,
#   'form': 1,
#   'toward': 1,
#   'outsid': 1,
#   'metal': 1,
#   'sheet': 1,
#   'layer': 1,
#   'sleev': 1,
#   '.': 1},
#  'The heat shield according to claim 18, wherein the first collar of the decoupling element comprises compressed sections, where different compressed sections may have a different degree of compression.': {'heat': 1,
#   'shield': 1,
#   'accord': 1,
#   'claim': 1,
#   '18': 1,
#   ',': 2,
#   'wherein': 1,
#   'first': 1,
#   'collar': 1,
#   'decoupl': 1,
#   'element': 1,
#   'compris': 1,
#   'compress': 3,
#   'section': 2,
#   'differ': 2,
#   'may': 1,
#   'degre': 1,
#   '.': 1},
#  'The heat shield according to claim 18, wherein the wall of the sleeve shows no recesses on its outer or inner circumference.': {'heat': 1,
#   'shield': 1,
#   'accord': 1,
#   'claim': 1,
#   '18': 1,
#   ',': 1,
#   'wherein': 1,
#   'wall': 1,
#   'sleev': 1,
#   'show': 1,
#   'recess': 1,
#   'outer': 1,
#   'inner': 1,
#   'circumfer': 1,
#   '.': 1},
#  'The heat shield according to claim 18, wherein the annular shank area of the sleeve comprises a circular, oval or elliptic cross section in the plane of the metal sheet layer.': {'heat': 1,
#   'shield': 1,
#   'accord': 1,
#   'claim': 1,
#   '18': 1,
#   ',': 2,
#   'wherein': 1,
#   'annular': 1,
#   'shank': 1,
#   'area': 1,
#   'sleev': 1,
#   'compris': 1,
#   'circular': 1,
#   'oval': 1,
#   'ellipt': 1,
#   'cross': 1,
#   'section': 1,
#   'plane': 1,
#   'metal': 1,
#   'sheet': 1,
#   'layer': 1,
#   '.': 1},
#  'The heat shield according to claim 18, wherein the second collar of the decoupling element comprises a circumferential recess extending along the passage opening of the decoupling element, where the s': {'heat': 1,
#   'shield': 1,
#   'accord': 1,
#   'claim': 1,
#   '18': 1,
#   ',': 2,
#   'wherein': 1,
#   'second': 2,
#   'collar': 2,
#   'decoupl': 2,
#   'element': 2,
#   'compris': 1,
#   'circumferenti': 1,
#   'recess': 1,
#   'extend': 1,
#   'along': 1,
#   'passag': 1,
#   'open': 1,
#   'engag': 1,
#   'sleev': 1,
#   '.': 1},
#  'The heat shield according to claim 18, wherein the edge of the passage opening of the metal sheet layer on both its surfaces is covered by the decoupling element in the radial direction over a width (': {'heat': 1,
#   'shield': 1,
#   'accord': 1,
#   'claim': 1,
#   '18': 1,
#   ',': 2,
#   'wherein': 1,
#   'edg': 1,
#   'passag': 2,
#   'open': 2,
#   'metal': 1,
#   'sheet': 1,
#   'layer': 1,
#   'surfac': 1,
#   'cover': 1,
#   'decoupl': 2,
#   'element': 2,
#   'radial': 1,
#   'direct': 1,
#   'width': 1,
#   '(': 2,
#   'b3': 1,
#   ')': 2,
#   'correspond': 1,
#   'least': 1,
#   '40': 1,
#   '%': 1,
#   'wall': 1,
#   'thick': 1,
#   'b10': 1,
#   'area': 1,
#   '.': 1},
#  'The heat shield according to claim 18, wherein the edge of the passage opening of the metal sheet layer relative to the plane (E), in which the metal sheet layer extends at the outer edge of the decou': {'heat': 1,
#   'shield': 1,
#   'accord': 1,
#   'claim': 1,
#   '18': 1,
#   ',': 3,
#   'wherein': 1,
#   'edg': 2,
#   'passag': 1,
#   'open': 1,
#   'metal': 2,
#   'sheet': 2,
#   'layer': 2,
#   'rel': 2,
#   'plane': 2,
#   '(': 2,
#   'e': 2,
#   ')': 2,
#   'extend': 1,
#   'outer': 1,
#   'decoupl': 1,
#   'element': 1,
#   'bent': 1,
#   'angl': 1,
#   'toward': 1,
#   'side': 1,
#   'first': 1,
#   'collar': 1,
#   '.': 1},
#  'The heat shield according to claim 18, wherein the decoupling element realizes a complete decoupling between the metallic layer and the sleeve, and/or between the metal sheet layer and a heat emitting': {'heat': 2,
#   'shield': 1,
#   'accord': 1,
#   'claim': 1,
#   '18': 1,
#   ',': 3,
#   'wherein': 1,
#   'decoupl': 2,
#   'element': 1,
#   'realiz': 1,
#   'complet': 1,
#   'metal': 4,
#   'layer': 4,
#   'sleev': 1,
#   'and/or': 2,
#   'sheet': 3,
#   'emit': 2,
#   'sound': 1,
#   'part': 1,
#   'orthogon': 1,
#   'plane': 2,
#   'direct': 1,
#   '.': 1},
#  'A heat shield for shielding of hot areas of a combustion engine, comprising at least one metal sheet layer with a first and a second surface, where the at least one metal sheet layer comprises at leas': {'heat': 1,
#   'shield': 2,
#   'hot': 1,
#   'area': 8,
#   'combust': 1,
#   'engin': 1,
#   ',': 15,
#   'compris': 3,
#   'least': 5,
#   'one': 3,
#   'metal': 2,
#   'sheet': 2,
#   'layer': 2,
#   'first': 7,
#   'second': 3,
#   'surfac': 3,
#   'passag': 12,
#   'open': 11,
#   'fasten': 2,
#   'element': 6,
#   'sleev': 6,
#   'penetr': 3,
#   'wherein': 1,
#   'onli': 1,
#   'decoupl': 4,
#   'flexibl': 1,
#   'materi': 1,
#   'arrang': 1,
#   'circumferenti': 3,
#   'edg': 3,
#   ')': 3,
#   'annular': 1,
#   'shank': 4,
#   'b': 1,
#   'collar': 6,
#   'extend': 4,
#   'radial': 3,
#   'outwardli': 3,
#   'c': 1,
#   'adjac': 1,
#   'region': 3,
#   'show': 1,
#   'constant': 1,
#   'wall': 3,
#   'thick': 3,
#   'transit': 2,
#   'section': 2,
#   'ha': 1,
#   'increas': 1,
#   'rel': 1,
#   'round': 1,
#   'inclin': 1,
#   '.': 1},
#  'The heat shield according to claim 32, wherein said transition area at least in sections extends such that a) the height H of the transition area in axial direction of the passage opening in said sect': {'heat': 1,
#   'shield': 1,
#   'accord': 1,
#   'claim': 1,
#   '32': 1,
#   ',': 4,
#   'wherein': 1,
#   'said': 4,
#   'transit': 4,
#   'area': 5,
#   'least': 3,
#   'section': 4,
#   'extend': 1,
#   ')': 3,
#   'height': 1,
#   'h': 1,
#   'axial': 2,
#   'direct': 2,
#   'passag': 3,
#   'open': 3,
#   'equal': 6,
#   'larger': 3,
#   '25': 1,
#   '%': 2,
#   'and/or': 5,
#   'smaller': 3,
#   '75': 1,
#   'inner': 1,
#   'diamet': 1,
#   'shank': 2,
#   ';': 2,
#   'b': 1,
#   'round': 1,
#   'ha': 1,
#   'radiu': 1,
#   'r': 1,
#   'curvatur': 1,
#   'first': 1,
#   'collar': 1,
#   '5': 2,
#   'mm': 3,
#   '6': 1,
#   'prefer': 2,
#   'mm≦5': 1,
#   'r≦6': 1,
#   'c': 1,
#   'inclin': 1,
#   'enclos': 1,
#   'angl': 1,
#   'β': 1,
#   '30°': 1,
#   '60°': 1,
#   '30°≦β≦60°': 1,
#   '.': 1},
#  'A method for the production of a heat shield for shielding of hot areas of a combustion engine, comprising at least one metal sheet layer with a first and a second surface, with the at least one metal': {'method': 1,
#   'product': 1,
#   'heat': 1,
#   'shield': 3,
#   'hot': 1,
#   'area': 1,
#   'combust': 1,
#   'engin': 1,
#   ',': 7,
#   'compris': 2,
#   'least': 3,
#   'one': 3,
#   'metal': 3,
#   'sheet': 3,
#   'layer': 3,
#   'first': 7,
#   'second': 1,
#   'surfac': 3,
#   'passag': 3,
#   'open': 3,
#   'fasten': 1,
#   'element': 5,
#   'sleev': 4,
#   'pass': 1,
#   'wherein': 2,
#   'decoupl': 4,
#   'flexibl': 1,
#   'materi': 1,
#   'insert': 2,
#   'dure': 1,
#   'thi': 1,
#   'compress': 1,
#   'collar': 4,
#   'order': 1,
#   'form': 1,
#   'extend': 1,
#   'radial': 1,
#   'along': 1,
#   '.': 1}}

# %% [markdown]
# <strong> TF Matrix Calcuation </strong>
# - <code> tf_matrix </code> dictionary is created to store the term frequency for each word in each sentence.
# - loop over the freq_matrix. sent will be the sentence, and f_table is the corresponding frequency table for that sentence.
# - For each sentence, a new empty dictionary <code> tf_table </code> is created. This will store the term frequencies for words in this particular sentence.
# - The function then iterates over each word and its count in the frequency table. It calculates the term frequency by dividing the count of each word by the total word count in the sentence, and stores this value in <code> tf_table. </code>
# - The term frequency table <code> tf_table </code> for each sentence is then stored in the  <code> tf_matrix </code> with the sentence as the key.

# %%
def _create_tf_matrix(freq_matrix):
    tf_matrix = {}

    for sent, f_table in freq_matrix.items():
        tf_table = {}

        count_words_in_sentence = len(f_table)
        for word, count in f_table.items():
            tf_table[word] = count / count_words_in_sentence

        tf_matrix[sent] = tf_table

    return tf_matrix

# %%
tf_matrix = _create_tf_matrix(freq_matrix)

# %% [markdown]
# ---

# %% [markdown]
# ### IDF Calculation

# %% [markdown]
# we calculate, “how many sentences contain a word”, Let’s call it Documents per words matrix.

# %%
def _create_documents_per_words(freq_matrix):
    word_per_doc_table = {}

    for sent, f_table in freq_matrix.items():
        for word, count in f_table.items():
            if word in word_per_doc_table:
                word_per_doc_table[word] += 1
            else:
                word_per_doc_table[word] = 1

    return word_per_doc_table

count_doc_per_words = _create_documents_per_words(freq_matrix)

# %%
count_doc_per_words
# Out:
# {'heat': 17,
#  'shield': 17,
#  'hot': 3,
#  'area': 10,
#  'combust': 3,
#  'engin': 3,
#  'compris': 7,
#  'least': 8,
#  'one': 4,
#  'metal': 10,
#  'sheet': 9,
#  'layer': 9,
#  'first': 9,
#  'second': 5,
#  'surfac': 4,
#  ',': 17,
#  'passag': 11,
#  'open': 11,
#  'fasten': 3,
#  'element': 11,
#  'sleev': 11,
#  'pass': 2,
#  'wherein': 17,
#  'decoupl': 11,
#  'flexibl': 3,
#  'materi': 5,
#  'arrang': 2,
#  'circumferenti': 4,
#  'edg': 4,
#  ';': 2,
#  ')': 6,
#  'annular': 3,
#  'shank': 7,
#  'penetr': 2,
#  'b': 3,
#  'collar': 11,
#  'extend': 6,
#  'radial': 7,
#  'outward': 1,
#  'rel': 3,
#  'c': 3,
#  'adjac': 2,
#  'region': 3,
#  'show': 6,
#  'constant': 2,
#  'wall': 5,
#  'thick': 6,
#  'transit': 6,
#  'section': 6,
#  'outwardli': 2,
#  'increas': 3,
#  'round': 3,
#  'inclin': 3,
#  '.': 17,
#  'accord': 14,
#  'claim': 14,
#  '18': 13,
#  'said': 2,
#  'compar': 1,
#  'respect': 1,
#  'locat': 1,
#  'circular': 2,
#  'segment': 1,
#  '90': 2,
#  '%': 4,
#  'extens': 2,
#  'distanc': 1,
#  'larger': 4,
#  'curvatur': 2,
#  'radiu': 2,
#  'inner': 3,
#  'diamet': 2,
#  '(': 3,
#  'di12': 1,
#  'di13': 1,
#  'compos': 1,
#  'wire': 1,
#  'mesh': 1,
#  'silicon': 1,
#  'form': 2,
#  'toward': 2,
#  'outsid': 1,
#  'compress': 2,
#  'differ': 1,
#  'may': 1,
#  'degre': 1,
#  'recess': 2,
#  'outer': 2,
#  'circumfer': 1,
#  'oval': 1,
#  'ellipt': 1,
#  'cross': 1,
#  'plane': 3,
#  'along': 2,
#  'engag': 1,
#  'cover': 1,
#  'direct': 3,
#  'width': 1,
#  'b3': 1,
#  'correspond': 1,
#  '40': 1,
#  'b10': 1,
#  'e': 1,
#  'bent': 1,
#  'angl': 2,
#  'side': 1,
#  'realiz': 1,
#  'complet': 1,
#  'and/or': 2,
#  'emit': 1,
#  'sound': 1,
#  'part': 1,
#  'orthogon': 1,
#  'onli': 1,
#  'ha': 2,
#  '32': 1,
#  'height': 1,
#  'h': 1,
#  'axial': 1,
#  'equal': 1,
#  '25': 1,
#  'smaller': 1,
#  '75': 1,
#  'r': 1,
#  '5': 1,
#  'mm': 1,
#  '6': 1,
#  'prefer': 1,
#  'mm≦5': 1,
#  'r≦6': 1,
#  'enclos': 1,
#  'β': 1,
#  '30°': 1,
#  '60°': 1,
#  '30°≦β≦60°': 1,
#  'method': 1,
#  'product': 1,
#  'insert': 1,
#  'dure': 1,
#  'thi': 1,
#  'order': 1}

# %% [markdown]
# The result means: 1 appear in 9 sentence and antioxid appears in 12 sentences etc etc...

# %% [markdown]
# after that, calcuate idf according to the formula <code> IDF(t) = log_e(Total number of documents / Number of documents with term t in it) </code> which is the number from the above result.

# %%
total_docs = len(combined_sentences_v10)
def _create_idf_matrix(freq_matrix, count_doc_per_words, total_documents):
    idf_matrix = {}

    for sent, f_table in freq_matrix.items():
        idf_table = {}

        for word in f_table.keys():
            idf_table[word] = math.log10(total_documents / float(count_doc_per_words[word]))

        idf_matrix[sent] = idf_table

    return idf_matrix
idf_matrix = _create_idf_matrix(freq_matrix, count_doc_per_words,total_docs)

# %%
idf_matrix
# Out:
# {'A heat shield for shielding hot areas of a combustion engine comprising at least one metal sheet layer with a first and a second surface, with the at least one metal sheet layer comprising at least on': {'heat': 0.0,
#   'shield': 0.0,
#   'hot': 0.7533276666586115,
#   'area': 0.2304489213782739,
#   'combust': 0.7533276666586115,
#   'engin': 0.7533276666586115,
#   'compris': 0.3853508813640171,
#   'least': 0.32735893438633035,
#   'one': 0.6283889300503115,
#   'metal': 0.2304489213782739,
#   'sheet': 0.27620641193894907,
#   'layer': 0.27620641193894907,
#   'first': 0.27620641193894907,
#   'second': 0.5314789170422551,
#   'surfac': 0.6283889300503115,
#   ',': 0.0,
#   'passag': 0.18905623622004888,
#   'open': 0.18905623622004888,
#   'fasten': 0.7533276666586115,
#   'element': 0.18905623622004888,
#   'sleev': 0.18905623622004888,
#   'pass': 0.9294189257142927,
#   'wherein': 0.0,
#   'decoupl': 0.18905623622004888,
#   'flexibl': 0.7533276666586115,
#   'materi': 0.5314789170422551,
#   'arrang': 0.9294189257142927,
#   'circumferenti': 0.6283889300503115,
#   'edg': 0.6283889300503115,
#   ';': 0.9294189257142927,
#   ')': 0.4522976709946303,
#   'annular': 0.7533276666586115,
#   'shank': 0.3853508813640171,
#   'penetr': 0.9294189257142927,
#   'b': 0.7533276666586115,
#   'collar': 0.18905623622004888,
#   'extend': 0.4522976709946303,
#   'radial': 0.3853508813640171,
#   'outward': 1.2304489213782739,
#   'rel': 0.7533276666586115,
#   'c': 0.7533276666586115,
#   'adjac': 0.9294189257142927,
#   'region': 0.7533276666586115,
#   'show': 0.4522976709946303,
#   'constant': 0.9294189257142927,
#   'wall': 0.5314789170422551,
#   'thick': 0.4522976709946303,
#   'transit': 0.4522976709946303,
#   'section': 0.4522976709946303,
#   'outwardli': 0.9294189257142927,
#   'increas': 0.7533276666586115,
#   'round': 0.7533276666586115,
#   'inclin': 0.7533276666586115,
#   '.': 0.0},
#  'The heat shield according to claim 18, wherein at least one of said sections of said transition area shows an increased radial wall thickness, each of these transition areas shows an increased radial ': {'heat': 0.0,
#   'shield': 0.0,
#   'accord': 0.08432088570003587,
#   'claim': 0.08432088570003587,
#   '18': 0.11650556907143717,
#   ',': 0.0,
#   'wherein': 0.0,
#   'least': 0.32735893438633035,
#   'one': 0.6283889300503115,
#   'said': 0.9294189257142927,
#   'section': 0.4522976709946303,
#   'transit': 0.4522976709946303,
#   'area': 0.2304489213782739,
#   'show': 0.4522976709946303,
#   'increas': 0.7533276666586115,
#   'radial': 0.3853508813640171,
#   'wall': 0.5314789170422551,
#   'thick': 0.4522976709946303,
#   'compar': 1.2304489213782739,
#   'respect': 1.2304489213782739,
#   'shank': 0.3853508813640171,
#   'region': 0.7533276666586115,
#   'passag': 0.18905623622004888,
#   'open': 0.18905623622004888,
#   'locat': 1.2304489213782739,
#   'circular': 0.9294189257142927,
#   'segment': 1.2304489213782739,
#   'sleev': 0.18905623622004888,
#   '.': 0.0},
#  'The heat shield according to claim 18, wherein the transition area between the shank area and the first collar of the sleeve on at least 90% of its circumferential extension shows a distance to the me': {'heat': 0.0,
#   'shield': 0.0,
#   'accord': 0.08432088570003587,
#   'claim': 0.08432088570003587,
#   '18': 0.11650556907143717,
#   ',': 0.0,
#   'wherein': 0.0,
#   'transit': 0.4522976709946303,
#   'area': 0.2304489213782739,
#   'shank': 0.3853508813640171,
#   'first': 0.27620641193894907,
#   'collar': 0.18905623622004888,
#   'sleev': 0.18905623622004888,
#   'least': 0.32735893438633035,
#   '90': 0.9294189257142927,
#   '%': 0.6283889300503115,
#   'circumferenti': 0.6283889300503115,
#   'extens': 0.9294189257142927,
#   'show': 0.4522976709946303,
#   'distanc': 1.2304489213782739,
#   'metal': 0.2304489213782739,
#   'sheet': 0.27620641193894907,
#   'layer': 0.27620641193894907,
#   'larger': 0.6283889300503115,
#   'materi': 0.5314789170422551,
#   'thick': 0.4522976709946303,
#   'passag': 0.18905623622004888,
#   'open': 0.18905623622004888,
#   '.': 0.0},
#  'The heat shield according to claim 18, wherein the transition area between the shank area and the first collar of the sleeve on at least 90% of its radial extension shows a radial curvature radius whi': {'heat': 0.0,
#   'shield': 0.0,
#   'accord': 0.08432088570003587,
#   'claim': 0.08432088570003587,
#   '18': 0.11650556907143717,
#   ',': 0.0,
#   'wherein': 0.0,
#   'transit': 0.4522976709946303,
#   'area': 0.2304489213782739,
#   'shank': 0.3853508813640171,
#   'first': 0.27620641193894907,
#   'collar': 0.18905623622004888,
#   'sleev': 0.18905623622004888,
#   'least': 0.32735893438633035,
#   '90': 0.9294189257142927,
#   '%': 0.6283889300503115,
#   'radial': 0.3853508813640171,
#   'extens': 0.9294189257142927,
#   'show': 0.4522976709946303,
#   'curvatur': 0.9294189257142927,
#   'radiu': 0.9294189257142927,
#   'larger': 0.6283889300503115,
#   'materi': 0.5314789170422551,
#   'thick': 0.4522976709946303,
#   'passag': 0.18905623622004888,
#   'open': 0.18905623622004888,
#   '.': 0.0},
#  'The heat shield according to claim 18, wherein the decoupling element in the area of its second collar comprises an inner diameter (Di12) which is larger than the inner diameter (Di13) in the area of ': {'heat': 0.0,
#   'shield': 0.0,
#   'accord': 0.08432088570003587,
#   'claim': 0.08432088570003587,
#   '18': 0.11650556907143717,
#   ',': 0.0,
#   'wherein': 0.0,
#   'decoupl': 0.18905623622004888,
#   'element': 0.18905623622004888,
#   'area': 0.2304489213782739,
#   'second': 0.5314789170422551,
#   'collar': 0.18905623622004888,
#   'compris': 0.3853508813640171,
#   'inner': 0.7533276666586115,
#   'diamet': 0.9294189257142927,
#   '(': 0.7533276666586115,
#   'di12': 1.2304489213782739,
#   ')': 0.4522976709946303,
#   'larger': 0.6283889300503115,
#   'di13': 1.2304489213782739,
#   'passag': 0.18905623622004888,
#   'open': 0.18905623622004888,
#   '.': 0.0},
#  'The heat shield according to claim 18, wherein the decoupling element is composed of metal wire mesh or silicone.': {'heat': 0.0,
#   'shield': 0.0,
#   'accord': 0.08432088570003587,
#   'claim': 0.08432088570003587,
#   '18': 0.11650556907143717,
#   ',': 0.0,
#   'wherein': 0.0,
#   'decoupl': 0.18905623622004888,
#   'element': 0.18905623622004888,
#   'compos': 1.2304489213782739,
#   'metal': 0.2304489213782739,
#   'wire': 1.2304489213782739,
#   'mesh': 1.2304489213782739,
#   'silicon': 1.2304489213782739,
#   '.': 0.0},
#  'The heat shield according to claim 18, wherein the first collar of the decoupling element is radially formed towards an outside between the metal sheet layer and the first collar of the sleeve.': {'heat': 0.0,
#   'shield': 0.0,
#   'accord': 0.08432088570003587,
#   'claim': 0.08432088570003587,
#   '18': 0.11650556907143717,
#   ',': 0.0,
#   'wherein': 0.0,
#   'first': 0.27620641193894907,
#   'collar': 0.18905623622004888,
#   'decoupl': 0.18905623622004888,
#   'element': 0.18905623622004888,
#   'radial': 0.3853508813640171,
#   'form': 0.9294189257142927,
#   'toward': 0.9294189257142927,
#   'outsid': 1.2304489213782739,
#   'metal': 0.2304489213782739,
#   'sheet': 0.27620641193894907,
#   'layer': 0.27620641193894907,
#   'sleev': 0.18905623622004888,
#   '.': 0.0},
#  'The heat shield according to claim 18, wherein the first collar of the decoupling element comprises compressed sections, where different compressed sections may have a different degree of compression.': {'heat': 0.0,
#   'shield': 0.0,
#   'accord': 0.08432088570003587,
#   'claim': 0.08432088570003587,
#   '18': 0.11650556907143717,
#   ',': 0.0,
#   'wherein': 0.0,
#   'first': 0.27620641193894907,
#   'collar': 0.18905623622004888,
#   'decoupl': 0.18905623622004888,
#   'element': 0.18905623622004888,
#   'compris': 0.3853508813640171,
#   'compress': 0.9294189257142927,
#   'section': 0.4522976709946303,
#   'differ': 1.2304489213782739,
#   'may': 1.2304489213782739,
#   'degre': 1.2304489213782739,
#   '.': 0.0},
#  'The heat shield according to claim 18, wherein the wall of the sleeve shows no recesses on its outer or inner circumference.': {'heat': 0.0,
#   'shield': 0.0,
#   'accord': 0.08432088570003587,
#   'claim': 0.08432088570003587,
#   '18': 0.11650556907143717,
#   ',': 0.0,
#   'wherein': 0.0,
#   'wall': 0.5314789170422551,
#   'sleev': 0.18905623622004888,
#   'show': 0.4522976709946303,
#   'recess': 0.9294189257142927,
#   'outer': 0.9294189257142927,
#   'inner': 0.7533276666586115,
#   'circumfer': 1.2304489213782739,
#   '.': 0.0},
#  'The heat shield according to claim 18, wherein the annular shank area of the sleeve comprises a circular, oval or elliptic cross section in the plane of the metal sheet layer.': {'heat': 0.0,
#   'shield': 0.0,
#   'accord': 0.08432088570003587,
#   'claim': 0.08432088570003587,
#   '18': 0.11650556907143717,
#   ',': 0.0,
#   'wherein': 0.0,
#   'annular': 0.7533276666586115,
#   'shank': 0.3853508813640171,
#   'area': 0.2304489213782739,
#   'sleev': 0.18905623622004888,
#   'compris': 0.3853508813640171,
#   'circular': 0.9294189257142927,
#   'oval': 1.2304489213782739,
#   'ellipt': 1.2304489213782739,
#   'cross': 1.2304489213782739,
#   'section': 0.4522976709946303,
#   'plane': 0.7533276666586115,
#   'metal': 0.2304489213782739,
#   'sheet': 0.27620641193894907,
#   'layer': 0.27620641193894907,
#   '.': 0.0},
#  'The heat shield according to claim 18, wherein the second collar of the decoupling element comprises a circumferential recess extending along the passage opening of the decoupling element, where the s': {'heat': 0.0,
#   'shield': 0.0,
#   'accord': 0.08432088570003587,
#   'claim': 0.08432088570003587,
#   '18': 0.11650556907143717,
#   ',': 0.0,
#   'wherein': 0.0,
#   'second': 0.5314789170422551,
#   'collar': 0.18905623622004888,
#   'decoupl': 0.18905623622004888,
#   'element': 0.18905623622004888,
#   'compris': 0.3853508813640171,
#   'circumferenti': 0.6283889300503115,
#   'recess': 0.9294189257142927,
#   'extend': 0.4522976709946303,
#   'along': 0.9294189257142927,
#   'passag': 0.18905623622004888,
#   'open': 0.18905623622004888,
#   'engag': 1.2304489213782739,
#   'sleev': 0.18905623622004888,
#   '.': 0.0},
#  'The heat shield according to claim 18, wherein the edge of the passage opening of the metal sheet layer on both its surfaces is covered by the decoupling element in the radial direction over a width (': {'heat': 0.0,
#   'shield': 0.0,
#   'accord': 0.08432088570003587,
#   'claim': 0.08432088570003587,
#   '18': 0.11650556907143717,
#   ',': 0.0,
#   'wherein': 0.0,
#   'edg': 0.6283889300503115,
#   'passag': 0.18905623622004888,
#   'open': 0.18905623622004888,
#   'metal': 0.2304489213782739,
#   'sheet': 0.27620641193894907,
#   'layer': 0.27620641193894907,
#   'surfac': 0.6283889300503115,
#   'cover': 1.2304489213782739,
#   'decoupl': 0.18905623622004888,
#   'element': 0.18905623622004888,
#   'radial': 0.3853508813640171,
#   'direct': 0.7533276666586115,
#   'width': 1.2304489213782739,
#   '(': 0.7533276666586115,
#   'b3': 1.2304489213782739,
#   ')': 0.4522976709946303,
#   'correspond': 1.2304489213782739,
#   'least': 0.32735893438633035,
#   '40': 1.2304489213782739,
#   '%': 0.6283889300503115,
#   'wall': 0.5314789170422551,
#   'thick': 0.4522976709946303,
#   'b10': 1.2304489213782739,
#   'area': 0.2304489213782739,
#   '.': 0.0},
#  'The heat shield according to claim 18, wherein the edge of the passage opening of the metal sheet layer relative to the plane (E), in which the metal sheet layer extends at the outer edge of the decou': {'heat': 0.0,
#   'shield': 0.0,
#   'accord': 0.08432088570003587,
#   'claim': 0.08432088570003587,
#   '18': 0.11650556907143717,
#   ',': 0.0,
#   'wherein': 0.0,
#   'edg': 0.6283889300503115,
#   'passag': 0.18905623622004888,
#   'open': 0.18905623622004888,
#   'metal': 0.2304489213782739,
#   'sheet': 0.27620641193894907,
#   'layer': 0.27620641193894907,
#   'rel': 0.7533276666586115,
#   'plane': 0.7533276666586115,
#   '(': 0.7533276666586115,
#   'e': 1.2304489213782739,
#   ')': 0.4522976709946303,
#   'extend': 0.4522976709946303,
#   'outer': 0.9294189257142927,
#   'decoupl': 0.18905623622004888,
#   'element': 0.18905623622004888,
#   'bent': 1.2304489213782739,
#   'angl': 0.9294189257142927,
#   'toward': 0.9294189257142927,
#   'side': 1.2304489213782739,
#   'first': 0.27620641193894907,
#   'collar': 0.18905623622004888,
#   '.': 0.0},
#  'The heat shield according to claim 18, wherein the decoupling element realizes a complete decoupling between the metallic layer and the sleeve, and/or between the metal sheet layer and a heat emitting': {'heat': 0.0,
#   'shield': 0.0,
#   'accord': 0.08432088570003587,
#   'claim': 0.08432088570003587,
#   '18': 0.11650556907143717,
#   ',': 0.0,
#   'wherein': 0.0,
#   'decoupl': 0.18905623622004888,
#   'element': 0.18905623622004888,
#   'realiz': 1.2304489213782739,
#   'complet': 1.2304489213782739,
#   'metal': 0.2304489213782739,
#   'layer': 0.27620641193894907,
#   'sleev': 0.18905623622004888,
#   'and/or': 0.9294189257142927,
#   'sheet': 0.27620641193894907,
#   'emit': 1.2304489213782739,
#   'sound': 1.2304489213782739,
#   'part': 1.2304489213782739,
#   'orthogon': 1.2304489213782739,
#   'plane': 0.7533276666586115,
#   'direct': 0.7533276666586115,
#   '.': 0.0},
#  'A heat shield for shielding of hot areas of a combustion engine, comprising at least one metal sheet layer with a first and a second surface, where the at least one metal sheet layer comprises at leas': {'heat': 0.0,
#   'shield': 0.0,
#   'hot': 0.7533276666586115,
#   'area': 0.2304489213782739,
#   'combust': 0.7533276666586115,
#   'engin': 0.7533276666586115,
#   ',': 0.0,
#   'compris': 0.3853508813640171,
#   'least': 0.32735893438633035,
#   'one': 0.6283889300503115,
#   'metal': 0.2304489213782739,
#   'sheet': 0.27620641193894907,
#   'layer': 0.27620641193894907,
#   'first': 0.27620641193894907,
#   'second': 0.5314789170422551,
#   'surfac': 0.6283889300503115,
#   'passag': 0.18905623622004888,
#   'open': 0.18905623622004888,
#   'fasten': 0.7533276666586115,
#   'element': 0.18905623622004888,
#   'sleev': 0.18905623622004888,
#   'penetr': 0.9294189257142927,
#   'wherein': 0.0,
#   'onli': 1.2304489213782739,
#   'decoupl': 0.18905623622004888,
#   'flexibl': 0.7533276666586115,
#   'materi': 0.5314789170422551,
#   'arrang': 0.9294189257142927,
#   'circumferenti': 0.6283889300503115,
#   'edg': 0.6283889300503115,
#   ')': 0.4522976709946303,
#   'annular': 0.7533276666586115,
#   'shank': 0.3853508813640171,
#   'b': 0.7533276666586115,
#   'collar': 0.18905623622004888,
#   'extend': 0.4522976709946303,
#   'radial': 0.3853508813640171,
#   'outwardli': 0.9294189257142927,
#   'c': 0.7533276666586115,
#   'adjac': 0.9294189257142927,
#   'region': 0.7533276666586115,
#   'show': 0.4522976709946303,
#   'constant': 0.9294189257142927,
#   'wall': 0.5314789170422551,
#   'thick': 0.4522976709946303,
#   'transit': 0.4522976709946303,
#   'section': 0.4522976709946303,
#   'ha': 0.9294189257142927,
#   'increas': 0.7533276666586115,
#   'rel': 0.7533276666586115,
#   'round': 0.7533276666586115,
#   'inclin': 0.7533276666586115,
#   '.': 0.0},
#  'The heat shield according to claim 32, wherein said transition area at least in sections extends such that a) the height H of the transition area in axial direction of the passage opening in said sect': {'heat': 0.0,
#   'shield': 0.0,
#   'accord': 0.08432088570003587,
#   'claim': 0.08432088570003587,
#   '32': 1.2304489213782739,
#   ',': 0.0,
#   'wherein': 0.0,
#   'said': 0.9294189257142927,
#   'transit': 0.4522976709946303,
#   'area': 0.2304489213782739,
#   'least': 0.32735893438633035,
#   'section': 0.4522976709946303,
#   'extend': 0.4522976709946303,
#   ')': 0.4522976709946303,
#   'height': 1.2304489213782739,
#   'h': 1.2304489213782739,
#   'axial': 1.2304489213782739,
#   'direct': 0.7533276666586115,
#   'passag': 0.18905623622004888,
#   'open': 0.18905623622004888,
#   'equal': 1.2304489213782739,
#   'larger': 0.6283889300503115,
#   '25': 1.2304489213782739,
#   '%': 0.6283889300503115,
#   'and/or': 0.9294189257142927,
#   'smaller': 1.2304489213782739,
#   '75': 1.2304489213782739,
#   'inner': 0.7533276666586115,
#   'diamet': 0.9294189257142927,
#   'shank': 0.3853508813640171,
#   ';': 0.9294189257142927,
#   'b': 0.7533276666586115,
#   'round': 0.7533276666586115,
#   'ha': 0.9294189257142927,
#   'radiu': 0.9294189257142927,
#   'r': 1.2304489213782739,
#   'curvatur': 0.9294189257142927,
#   'first': 0.27620641193894907,
#   'collar': 0.18905623622004888,
#   '5': 1.2304489213782739,
#   'mm': 1.2304489213782739,
#   '6': 1.2304489213782739,
#   'prefer': 1.2304489213782739,
#   'mm≦5': 1.2304489213782739,
#   'r≦6': 1.2304489213782739,
#   'c': 0.7533276666586115,
#   'inclin': 0.7533276666586115,
#   'enclos': 1.2304489213782739,
#   'angl': 0.9294189257142927,
#   'β': 1.2304489213782739,
#   '30°': 1.2304489213782739,
#   '60°': 1.2304489213782739,
#   '30°≦β≦60°': 1.2304489213782739,
#   '.': 0.0},
#  'A method for the production of a heat shield for shielding of hot areas of a combustion engine, comprising at least one metal sheet layer with a first and a second surface, with the at least one metal': {'method': 1.2304489213782739,
#   'product': 1.2304489213782739,
#   'heat': 0.0,
#   'shield': 0.0,
#   'hot': 0.7533276666586115,
#   'area': 0.2304489213782739,
#   'combust': 0.7533276666586115,
#   'engin': 0.7533276666586115,
#   ',': 0.0,
#   'compris': 0.3853508813640171,
#   'least': 0.32735893438633035,
#   'one': 0.6283889300503115,
#   'metal': 0.2304489213782739,
#   'sheet': 0.27620641193894907,
#   'layer': 0.27620641193894907,
#   'first': 0.27620641193894907,
#   'second': 0.5314789170422551,
#   'surfac': 0.6283889300503115,
#   'passag': 0.18905623622004888,
#   'open': 0.18905623622004888,
#   'fasten': 0.7533276666586115,
#   'element': 0.18905623622004888,
#   'sleev': 0.18905623622004888,
#   'pass': 0.9294189257142927,
#   'wherein': 0.0,
#   'decoupl': 0.18905623622004888,
#   'flexibl': 0.7533276666586115,
#   'materi': 0.5314789170422551,
#   'insert': 1.2304489213782739,
#   'dure': 1.2304489213782739,
#   'thi': 1.2304489213782739,
#   'compress': 0.9294189257142927,
#   'collar': 0.18905623622004888,
#   'order': 1.2304489213782739,
#   'form': 0.9294189257142927,
#   'extend': 0.4522976709946303,
#   'radial': 0.3853508813640171,
#   'along': 0.9294189257142927,
#   '.': 0.0}}

# %% [markdown]
# ### Calcualte TFIDF

# %%
def _create_tf_idf_matrix(tf_matrix, idf_matrix):
    tf_idf_matrix = {}

    for (sent1, f_table1), (sent2, f_table2) in zip(tf_matrix.items(), idf_matrix.items()):
        tf_idf_table = {}
        for (word1, value1), (word2, value2) in zip(f_table1.items(), f_table2.items()):
            # Reduce the weight for numerals
            if word1.isdigit():
                tf_idf_table[word1] = 0
            else:
                tf_idf_table[word1] = float(value1 * value2)

        tf_idf_matrix[sent1] = tf_idf_table

    return tf_idf_matrix


tf_idf_matrix = _create_tf_idf_matrix(tf_matrix, idf_matrix)

# %%
tf_idf_matrix
# Out:
# {'A heat shield for shielding hot areas of a combustion engine comprising at least one metal sheet layer with a first and a second surface, with the at least one metal sheet layer comprising at least on': {'heat': 0.0,
#   'shield': 0.0,
#   'hot': 0.013950512345529843,
#   'area': 0.034140580944929465,
#   'combust': 0.013950512345529843,
#   'engin': 0.013950512345529843,
#   'compris': 0.021408382298000947,
#   'least': 0.030311012443178735,
#   'one': 0.03491049611390619,
#   'metal': 0.008535145236232366,
#   'sheet': 0.010229867108849966,
#   'layer': 0.010229867108849966,
#   'first': 0.035804534880974875,
#   'second': 0.029526606502347508,
#   'surfac': 0.03491049611390619,
#   ',': 0.0,
#   'passag': 0.038511455526306256,
#   'open': 0.03501041411482386,
#   'fasten': 0.013950512345529843,
#   'element': 0.014004165645929547,
#   'sleev': 0.01750520705741193,
#   'pass': 0.017211461587301715,
#   'wherein': 0.0,
#   'decoupl': 0.01050312423444716,
#   'flexibl': 0.013950512345529843,
#   'materi': 0.009842202167449169,
#   'arrang': 0.017211461587301715,
#   'circumferenti': 0.03491049611390619,
#   'edg': 0.03491049611390619,
#   ';': 0.017211461587301715,
#   ')': 0.025127648388590572,
#   'annular': 0.013950512345529843,
#   'shank': 0.028544509730667928,
#   'penetr': 0.017211461587301715,
#   'b': 0.013950512345529843,
#   'collar': 0.02100624846889432,
#   'extend': 0.03350353118478743,
#   'radial': 0.03568063716333491,
#   'outward': 0.0455721822732694,
#   'rel': 0.041851537036589524,
#   'c': 0.013950512345529843,
#   'adjac': 0.017211461587301715,
#   'region': 0.041851537036589524,
#   'show': 0.016751765592393716,
#   'constant': 0.017211461587301715,
#   'wall': 0.019684404334898337,
#   'thick': 0.016751765592393716,
#   'transit': 0.016751765592393716,
#   'section': 0.016751765592393716,
#   'outwardli': 0.017211461587301715,
#   'increas': 0.013950512345529843,
#   'round': 0.013950512345529843,
#   'inclin': 0.013950512345529843,
#   '.': 0.0},
#  'The heat shield according to claim 18, wherein at least one of said sections of said transition area shows an increased radial wall thickness, each of these transition areas shows an increased radial ': {'heat': 0.0,
#   'shield': 0.0,
#   'accord': 0.002907616748277099,
#   'claim': 0.002907616748277099,
#   '18': 0,
#   ',': 0.0,
#   'wherein': 0.0,
#   'least': 0.011288239116770012,
#   'one': 0.021668583794838325,
#   'said': 0.0640978569458133,
#   'section': 0.06238588565443177,
#   'transit': 0.04678941424082383,
#   'area': 0.03178605812114123,
#   'show': 0.031192942827215884,
#   'increas': 0.05195363218335252,
#   'radial': 0.026575922852690833,
#   'wall': 0.054980577625060874,
#   'thick': 0.04678941424082383,
#   'compar': 0.04242927315097496,
#   'respect': 0.08485854630194992,
#   'shank': 0.026575922852690833,
#   'region': 0.02597681609167626,
#   'passag': 0.00651918055931203,
#   'open': 0.00651918055931203,
#   'locat': 0.04242927315097496,
#   'circular': 0.03204892847290665,
#   'segment': 0.04242927315097496,
#   'sleev': 0.00651918055931203,
#   '.': 0.0},
#  'The heat shield according to claim 18, wherein the transition area between the shank area and the first collar of the sleeve on at least 90% of its circumferential extension shows a distance to the me': {'heat': 0.0,
#   'shield': 0.0,
#   'accord': 0.002907616748277099,
#   'claim': 0.002907616748277099,
#   '18': 0,
#   ',': 0.0,
#   'wherein': 0.0,
#   'transit': 0.015596471413607942,
#   'area': 0.03178605812114123,
#   'shank': 0.026575922852690833,
#   'first': 0.009524359032377553,
#   'collar': 0.00651918055931203,
#   'sleev': 0.01303836111862406,
#   'least': 0.011288239116770012,
#   '90': 0,
#   '%': 0.021668583794838325,
#   'circumferenti': 0.021668583794838325,
#   'extens': 0.03204892847290665,
#   'show': 0.015596471413607942,
#   'distanc': 0.04242927315097496,
#   'metal': 0.007946514530285307,
#   'sheet': 0.009524359032377553,
#   'layer': 0.009524359032377553,
#   'larger': 0.021668583794838325,
#   'materi': 0.018326859208353627,
#   'thick': 0.015596471413607942,
#   'passag': 0.00651918055931203,
#   'open': 0.00651918055931203,
#   '.': 0.0},
#  'The heat shield according to claim 18, wherein the transition area between the shank area and the first collar of the sleeve on at least 90% of its radial extension shows a radial curvature radius whi': {'heat': 0.0,
#   'shield': 0.0,
#   'accord': 0.003122995766667995,
#   'claim': 0.003122995766667995,
#   '18': 0,
#   ',': 0.0,
#   'wherein': 0.0,
#   'transit': 0.016751765592393716,
#   'area': 0.034140580944929465,
#   'shank': 0.028544509730667928,
#   'first': 0.010229867108849966,
#   'collar': 0.007002082822964773,
#   'sleev': 0.014004165645929547,
#   'least': 0.012124404977271493,
#   '90': 0,
#   '%': 0.02327366407593746,
#   'radial': 0.028544509730667928,
#   'extens': 0.03442292317460343,
#   'show': 0.016751765592393716,
#   'curvatur': 0.03442292317460343,
#   'radiu': 0.03442292317460343,
#   'larger': 0.02327366407593746,
#   'materi': 0.019684404334898337,
#   'thick': 0.016751765592393716,
#   'passag': 0.007002082822964773,
#   'open': 0.007002082822964773,
#   '.': 0.0},
#  'The heat shield according to claim 18, wherein the decoupling element in the area of its second collar comprises an inner diameter (Di12) which is larger than the inner diameter (Di13) in the area of ': {'heat': 0.0,
#   'shield': 0.0,
#   'accord': 0.003666125465218951,
#   'claim': 0.003666125465218951,
#   '18': 0,
#   ',': 0.0,
#   'wherein': 0.0,
#   'decoupl': 0.00821983635739343,
#   'element': 0.00821983635739343,
#   'area': 0.020039036641589035,
#   'second': 0.023107779001837178,
#   'collar': 0.00821983635739343,
#   'compris': 0.01675438614626161,
#   'inner': 0.06550675362248795,
#   'diamet': 0.08081903701863415,
#   '(': 0.06550675362248795,
#   'di12': 0.05349777919035973,
#   ')': 0.03933023226040264,
#   'larger': 0.027321257828274412,
#   'di13': 0.05349777919035973,
#   'passag': 0.00821983635739343,
#   'open': 0.00821983635739343,
#   '.': 0.0},
#  'The heat shield according to claim 18, wherein the decoupling element is composed of metal wire mesh or silicone.': {'heat': 0.0,
#   'shield': 0.0,
#   'accord': 0.005621392380002392,
#   'claim': 0.005621392380002392,
#   '18': 0,
#   ',': 0.0,
#   'wherein': 0.0,
#   'decoupl': 0.012603749081336593,
#   'element': 0.012603749081336593,
#   'compos': 0.08202992809188492,
#   'metal': 0.015363261425218261,
#   'wire': 0.08202992809188492,
#   'mesh': 0.08202992809188492,
#   'silicon': 0.08202992809188492,
#   '.': 0.0},
#  'The heat shield according to claim 18, wherein the first collar of the decoupling element is radially formed towards an outside between the metal sheet layer and the first collar of the sleeve.': {'heat': 0.0,
#   'shield': 0.0,
#   'accord': 0.004216044285001794,
#   'claim': 0.004216044285001794,
#   '18': 0,
#   ',': 0.0,
#   'wherein': 0.0,
#   'first': 0.02762064119389491,
#   'collar': 0.01890562362200489,
#   'decoupl': 0.009452811811002444,
#   'element': 0.009452811811002444,
#   'radial': 0.019267544068200856,
#   'form': 0.04647094628571464,
#   'toward': 0.04647094628571464,
#   'outsid': 0.061522446068913696,
#   'metal': 0.011522446068913696,
#   'sheet': 0.013810320596947454,
#   'layer': 0.013810320596947454,
#   'sleev': 0.009452811811002444,
#   '.': 0.0},
#  'The heat shield according to claim 18, wherein the first collar of the decoupling element comprises compressed sections, where different compressed sections may have a different degree of compression.': {'heat': 0.0,
#   'shield': 0.0,
#   'accord': 0.004684493650001993,
#   'claim': 0.004684493650001993,
#   '18': 0,
#   ',': 0.0,
#   'wherein': 0.0,
#   'first': 0.015344800663274948,
#   'collar': 0.01050312423444716,
#   'decoupl': 0.01050312423444716,
#   'element': 0.01050312423444716,
#   'compris': 0.021408382298000947,
#   'compress': 0.15490315428571544,
#   'section': 0.050255296777181144,
#   'differ': 0.13671654681980822,
#   'may': 0.06835827340990411,
#   'degre': 0.06835827340990411,
#   '.': 0.0},
#  'The heat shield according to claim 18, wherein the wall of the sleeve shows no recesses on its outer or inner circumference.': {'heat': 0.0,
#   'shield': 0.0,
#   'accord': 0.005621392380002392,
#   'claim': 0.005621392380002392,
#   '18': 0,
#   ',': 0.0,
#   'wherein': 0.0,
#   'wall': 0.03543192780281701,
#   'sleev': 0.012603749081336593,
#   'show': 0.030153178066308687,
#   'recess': 0.06196126171428618,
#   'outer': 0.06196126171428618,
#   'inner': 0.05022184444390743,
#   'circumfer': 0.08202992809188492,
#   '.': 0.0},
#  'The heat shield according to claim 18, wherein the annular shank area of the sleeve comprises a circular, oval or elliptic cross section in the plane of the metal sheet layer.': {'heat': 0.0,
#   'shield': 0.0,
#   'accord': 0.0038327675318198125,
#   'claim': 0.0038327675318198125,
#   '18': 0,
#   ',': 0.0,
#   'wherein': 0.0,
#   'annular': 0.034242166666300526,
#   'shank': 0.017515949152909868,
#   'area': 0.010474950971739724,
#   'sleev': 0.008593465282729496,
#   'compris': 0.017515949152909868,
#   'circular': 0.042246314805195126,
#   'oval': 0.055929496426285176,
#   'ellipt': 0.055929496426285176,
#   'cross': 0.055929496426285176,
#   'section': 0.02055898504521047,
#   'plane': 0.034242166666300526,
#   'metal': 0.010474950971739724,
#   'sheet': 0.012554836906315868,
#   'layer': 0.012554836906315868,
#   '.': 0.0},
#  'The heat shield according to claim 18, wherein the second collar of the decoupling element comprises a circumferential recess extending along the passage opening of the decoupling element, where the s': {'heat': 0.0,
#   'shield': 0.0,
#   'accord': 0.00401528027143028,
#   'claim': 0.00401528027143028,
#   '18': 0,
#   ',': 0.0,
#   'wherein': 0.0,
#   'second': 0.05061703971831001,
#   'collar': 0.018005355830480844,
#   'decoupl': 0.018005355830480844,
#   'element': 0.018005355830480844,
#   'compris': 0.018350041969715097,
#   'circumferenti': 0.029923282383348165,
#   'recess': 0.04425804408163299,
#   'extend': 0.02153798433307763,
#   'along': 0.04425804408163299,
#   'passag': 0.009002677915240422,
#   'open': 0.009002677915240422,
#   'engag': 0.0585928057799178,
#   'sleev': 0.009002677915240422,
#   '.': 0.0},
#  'The heat shield according to claim 18, wherein the edge of the passage opening of the metal sheet layer on both its surfaces is covered by the decoupling element in the radial direction over a width (': {'heat': 0.0,
#   'shield': 0.0,
#   'accord': 0.002635027678126121,
#   'claim': 0.002635027678126121,
#   '18': 0,
#   ',': 0.0,
#   'wherein': 0.0,
#   'edg': 0.019637154064072234,
#   'passag': 0.011816014763753055,
#   'open': 0.011816014763753055,
#   'metal': 0.00720152879307106,
#   'sheet': 0.008631450373092158,
#   'layer': 0.008631450373092158,
#   'surfac': 0.019637154064072234,
#   'cover': 0.03845152879307106,
#   'decoupl': 0.011816014763753055,
#   'element': 0.011816014763753055,
#   'radial': 0.012042215042625534,
#   'direct': 0.02354148958308161,
#   'width': 0.03845152879307106,
#   '(': 0.04708297916616322,
#   'b3': 0.03845152879307106,
#   ')': 0.028268604437164394,
#   'correspond': 0.03845152879307106,
#   'least': 0.010229966699572823,
#   '40': 0,
#   '%': 0.019637154064072234,
#   'wall': 0.016608716157570473,
#   'thick': 0.014134302218582197,
#   'b10': 0.03845152879307106,
#   'area': 0.00720152879307106,
#   '.': 0.0},
#  'The heat shield according to claim 18, wherein the edge of the passage opening of the metal sheet layer relative to the plane (E), in which the metal sheet layer extends at the outer edge of the decou': {'heat': 0.0,
#   'shield': 0.0,
#   'accord': 0.002907616748277099,
#   'claim': 0.002907616748277099,
#   '18': 0,
#   ',': 0.0,
#   'wherein': 0.0,
#   'edg': 0.04333716758967665,
#   'passag': 0.00651918055931203,
#   'open': 0.00651918055931203,
#   'metal': 0.015893029060570614,
#   'sheet': 0.019048718064755107,
#   'layer': 0.019048718064755107,
#   'rel': 0.05195363218335252,
#   'plane': 0.05195363218335252,
#   '(': 0.05195363218335252,
#   'e': 0.08485854630194992,
#   ')': 0.031192942827215884,
#   'extend': 0.015596471413607942,
#   'outer': 0.03204892847290665,
#   'decoupl': 0.00651918055931203,
#   'element': 0.00651918055931203,
#   'bent': 0.04242927315097496,
#   'angl': 0.03204892847290665,
#   'toward': 0.03204892847290665,
#   'side': 0.04242927315097496,
#   'first': 0.009524359032377553,
#   'collar': 0.00651918055931203,
#   '.': 0.0},
#  'The heat shield according to claim 18, wherein the decoupling element realizes a complete decoupling between the metallic layer and the sleeve, and/or between the metal sheet layer and a heat emitting': {'heat': 0.0,
#   'shield': 0.0,
#   'accord': 0.003666125465218951,
#   'claim': 0.003666125465218951,
#   '18': 0,
#   ',': 0.0,
#   'wherein': 0.0,
#   'decoupl': 0.01643967271478686,
#   'element': 0.00821983635739343,
#   'realiz': 0.05349777919035973,
#   'complet': 0.05349777919035973,
#   'metal': 0.04007807328317807,
#   'layer': 0.04803589772851288,
#   'sleev': 0.00821983635739343,
#   'and/or': 0.08081903701863415,
#   'sheet': 0.03602692329638466,
#   'emit': 0.10699555838071946,
#   'sound': 0.05349777919035973,
#   'part': 0.05349777919035973,
#   'orthogon': 0.05349777919035973,
#   'plane': 0.06550675362248795,
#   'direct': 0.032753376811243975,
#   '.': 0.0},
#  'A heat shield for shielding of hot areas of a combustion engine, comprising at least one metal sheet layer with a first and a second surface, where the at least one metal sheet layer comprises at leas': {'heat': 0.0,
#   'shield': 0.0,
#   'hot': 0.014213729559596443,
#   'area': 0.03478474284955078,
#   'combust': 0.014213729559596443,
#   'engin': 0.014213729559596443,
#   ',': 0.0,
#   'compris': 0.021812314039472664,
#   'least': 0.030882918338333055,
#   'one': 0.03556918471982895,
#   'metal': 0.008696185712387694,
#   'sheet': 0.010422883469394304,
#   'layer': 0.010422883469394304,
#   'first': 0.03648009214288007,
#   'second': 0.03008371228541067,
#   'surfac': 0.03556918471982895,
#   'passag': 0.04280518555925635,
#   'open': 0.039238086762651656,
#   'fasten': 0.028427459119192887,
#   'element': 0.021402592779628176,
#   'sleev': 0.021402592779628176,
#   'penetr': 0.05260861843665808,
#   'wherein': 0.0,
#   'onli': 0.023216017384495732,
#   'decoupl': 0.014268395186418783,
#   'flexibl': 0.014213729559596443,
#   'materi': 0.010027904095136889,
#   'arrang': 0.017536206145552694,
#   'circumferenti': 0.03556918471982895,
#   'edg': 0.03556918471982895,
#   ')': 0.025601754961960207,
#   'annular': 0.014213729559596443,
#   'shank': 0.02908308538596355,
#   'b': 0.014213729559596443,
#   'collar': 0.021402592779628176,
#   'extend': 0.034135673282613604,
#   'radial': 0.021812314039472664,
#   'outwardli': 0.05260861843665808,
#   'c': 0.014213729559596443,
#   'adjac': 0.017536206145552694,
#   'region': 0.042641188678789334,
#   'show': 0.008533918320653401,
#   'constant': 0.017536206145552694,
#   'wall': 0.03008371228541067,
#   'thick': 0.025601754961960207,
#   'transit': 0.017067836641306802,
#   'section': 0.017067836641306802,
#   'ha': 0.017536206145552694,
#   'increas': 0.014213729559596443,
#   'rel': 0.014213729559596443,
#   'round': 0.014213729559596443,
#   'inclin': 0.014213729559596443,
#   '.': 0.0},
#  'The heat shield according to claim 32, wherein said transition area at least in sections extends such that a) the height H of the transition area in axial direction of the passage opening in said sect': {'heat': 0.0,
#   'shield': 0.0,
#   'accord': 0.0015614978833339975,
#   'claim': 0.0015614978833339975,
#   '32': 0,
#   ',': 0.0,
#   'wherein': 0.0,
#   'said': 0.06884584634920686,
#   'transit': 0.03350353118478743,
#   'area': 0.021337863090580916,
#   'least': 0.01818660746590724,
#   'section': 0.03350353118478743,
#   'extend': 0.008375882796196858,
#   ')': 0.025127648388590572,
#   'height': 0.0227860911366347,
#   'h': 0.0227860911366347,
#   'axial': 0.0455721822732694,
#   'direct': 0.027901024691059685,
#   'passag': 0.01050312423444716,
#   'open': 0.01050312423444716,
#   'equal': 0.13671654681980822,
#   'larger': 0.03491049611390619,
#   '25': 0,
#   '%': 0.02327366407593746,
#   'and/or': 0.08605730793650858,
#   'smaller': 0.06835827340990411,
#   '75': 0,
#   'inner': 0.013950512345529843,
#   'diamet': 0.017211461587301715,
#   'shank': 0.014272254865333964,
#   ';': 0.03442292317460343,
#   'b': 0.013950512345529843,
#   'round': 0.013950512345529843,
#   'ha': 0.017211461587301715,
#   'radiu': 0.017211461587301715,
#   'r': 0.0227860911366347,
#   'curvatur': 0.017211461587301715,
#   'first': 0.005114933554424983,
#   'collar': 0.0035010414114823867,
#   '5': 0,
#   'mm': 0.06835827340990411,
#   '6': 0,
#   'prefer': 0.0455721822732694,
#   'mm≦5': 0.0227860911366347,
#   'r≦6': 0.0227860911366347,
#   'c': 0.013950512345529843,
#   'inclin': 0.013950512345529843,
#   'enclos': 0.0227860911366347,
#   'angl': 0.017211461587301715,
#   'β': 0.0227860911366347,
#   '30°': 0.0227860911366347,
#   '60°': 0.0227860911366347,
#   '30°≦β≦60°': 0.0227860911366347,
#   '.': 0.0},
#  'A method for the production of a heat shield for shielding of hot areas of a combustion engine, comprising at least one metal sheet layer with a first and a second surface, with the at least one metal': {'method': 0.03154997234303266,
#   'product': 0.03154997234303266,
#   'heat': 0.0,
#   'shield': 0.0,
#   'hot': 0.019316094016887473,
#   'area': 0.005908946702007023,
#   'combust': 0.019316094016887473,
#   'engin': 0.019316094016887473,
#   ',': 0.0,
#   'compris': 0.01976158365969318,
#   'least': 0.025181456491256183,
#   'one': 0.048337610003870116,
#   'metal': 0.01772684010602107,
#   'sheet': 0.021246647072226853,
#   'layer': 0.021246647072226853,
#   'first': 0.049575509835195986,
#   'second': 0.013627664539545004,
#   'surfac': 0.048337610003870116,
#   'passag': 0.014542787401542223,
#   'open': 0.014542787401542223,
#   'fasten': 0.019316094016887473,
#   'element': 0.024237979002570367,
#   'sleev': 0.019390383202056296,
#   'pass': 0.023831254505494684,
#   'wherein': 0.0,
#   'decoupl': 0.019390383202056296,
#   'flexibl': 0.019316094016887473,
#   'materi': 0.013627664539545004,
#   'insert': 0.06309994468606532,
#   'dure': 0.03154997234303266,
#   'thi': 0.03154997234303266,
#   'compress': 0.023831254505494684,
#   'collar': 0.019390383202056296,
#   'order': 0.03154997234303266,
#   'form': 0.023831254505494684,
#   'extend': 0.011597376179349495,
#   'radial': 0.00988079182984659,
#   'along': 0.023831254505494684,
#   '.': 0.0}}

# %% [markdown]
# ### Score the sentence

# %%
def _score_sentences(tf_idf_matrix) -> dict:
    sentenceValue = {}

    for sent, f_table in tf_idf_matrix.items():
        total_score_per_sentence = 0
        count_words_in_sentence = len(f_table)

        for word, score in f_table.items():
            # Reduce the score for repetitive phrases
            if 'claim' in word:  # Example criterion, adjust as needed
                score *= 0.5  # Reduce the weight of these words

            total_score_per_sentence += score

        sentenceValue[sent] = total_score_per_sentence / count_words_in_sentence

    return sentenceValue


sentenceValue= _score_sentences(tf_idf_matrix)

# %%
sentenceValue
# Out:
# {'A heat shield for shielding hot areas of a combustion engine comprising at least one metal sheet layer with a first and a second surface, with the at least one metal sheet layer comprising at least on': 0.019980920641194323,
#  'The heat shield according to claim 18, wherein at least one of said sections of said transition area shows an increased radial wall thickness, each of these transition areas shows an increased radial ': 0.02655777681294699,
#  'The heat shield according to claim 18, wherein the transition area between the shank area and the first collar of the sleeve on at least 90% of its circumferential extension shows a distance to the me': 0.01199059883084724,
#  'The heat shield according to claim 18, wherein the transition area between the shank area and the first collar of the sleeve on at least 90% of its radial extension shows a radial curvature radius whi': 0.013816095520184346,
#  'The heat shield according to claim 18, wherein the decoupling element in the area of its second collar comprises an inner diameter (Di12) which is larger than the inner diameter (Di13) in the area of ': 0.02139039845684739,
#  'The heat shield according to claim 18, wherein the decoupling element is composed of metal wire mesh or silicone.': 0.025141504035028978,
#  'The heat shield according to claim 18, wherein the first collar of the decoupling element is radially formed towards an outside between the metal sheet layer and the first collar of the sleeve.': 0.014704186832388114,
#  'The heat shield according to claim 18, wherein the first collar of the decoupling element comprises compressed sections, where different compressed sections may have a different degree of compression.': 0.030771157824562967,
#  'The heat shield according to claim 18, wherein the wall of the sleeve shows no recesses on its outer or inner circumference.': 0.022853015965655372,
#  'The heat shield according to claim 18, wherein the annular shank area of the sleeve comprises a circular, oval or elliptic cross section in the plane of the metal sheet layer.': 0.01793237332292056,
#  'The heat shield according to claim 18, wherein the second collar of the decoupling element comprises a circumferential recess extending along the passage opening of the decoupling element, where the s': 0.016884964951997324,
#  'The heat shield according to claim 18, wherein the edge of the passage opening of the metal sheet layer on both its surfaces is covered by the decoupling element in the radial direction over a width (': 0.01518624807396438,
#  'The heat shield according to claim 18, wherein the edge of the passage opening of the metal sheet layer relative to the plane (E), in which the metal sheet layer extends at the outer edge of the decou': 0.02111460374291766,
#  'The heat shield according to claim 18, wherein the decoupling element realizes a complete decoupling between the metallic layer and the sleeve, and/or between the metal sheet layer and a heat emitting': 0.031134045640015734,
#  'A heat shield for shielding of hot areas of a combustion engine, comprising at least one metal sheet layer with a first and a second surface, where the at least one metal sheet layer comprises at leas': 0.02134708414042833,
#  'The heat shield according to claim 32, wherein said transition area at least in sections extends such that a) the height H of the transition area in axial direction of the passage opening in said sect': 0.022406135014701276,
#  'A method for the production of a heat shield for shielding of hot areas of a combustion engine, comprising at least one metal sheet layer with a first and a second surface, with the at least one metal': 0.021289906306515956}

# %%
def _find_average_score(sentenceValue) -> int:
    """
    Find the average score from the sentence value dictionary
    :rtype: int
    """
    sumValues = 0
    for entry in sentenceValue:
        sumValues += sentenceValue[entry]

    # Average value of a sentence from original summary_text
    average = (sumValues / len(sentenceValue))

    return average
threshold = _find_average_score(sentenceValue)

# %%
threshold
# Out:
# 0.020853000947830408

# %%
def _generate_summary(sentences, sentenceValue, threshold):
    sentence_count = 0
    summary = ''

    for sentence in sentences:
        if sentence[:len(sentence)] in sentenceValue and sentenceValue[sentence[:len(sentence)]] >= (threshold):
            # Additional check to avoid sentences with only numerals or very short content
            if len(sentence.split()) > 5 and not sentence.strip().isdigit():
                summary += " " + sentence
                sentence_count += 1

    return summary


tfidf_summary = _generate_summary(combined_sentences_v10, sentenceValue, threshold)

# %% [markdown]
# ### Generate the summary

# %%
tfidf_summary
# Out:
# ' The heat shield according to claim 18, wherein the decoupling element is composed of metal wire mesh or silicone. The heat shield according to claim 18, wherein the first collar of the decoupling element comprises compressed sections, where different compressed sections may have a different degree of compression. The heat shield according to claim 18, wherein the wall of the sleeve shows no recesses on its outer or inner circumference.'

# %% [markdown]
# ---

# %% [markdown]
# ### abstractive with chargpt

# %%
import openai
# openai.api_key = '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' #Rei's
openai.api_key = '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' #raja's

# %%
text_to_summarize = '\n'.join(combined_sentences_v10)
request_text = f"Summarize the following text:\n{text_to_summarize}"

# %%
response = openai.Completion.create(
  model="text-davinci-003",
  prompt=request_text,
  temperature=0.7,
  max_tokens=150
)

# Extract the summary from the response
summary = response.choices[0].text.strip()
print("Summary:", summary)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 response = openai.Completion.create(
#       2   model="text-davinci-003",
#       3   prompt=request_text,
#       4   temperature=0.7,
#       5   max_tokens=150
#       6 )
#       8 # Extract the summary from the response
#       9 summary = response.choices[0].text.strip()
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/nlp/lib/python3.11/site-packages/openai/api_resources/completion.py:25, in Completion.create(cls, *args, **kwargs)
#      23 while True:
#      24     try:
# ---> 25         return super().create(*args, **kwargs)
#      26     except TryAgain as e:
#      27         if timeout is not None and time.time() > start + timeout:
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/nlp/lib/python3.11/site-packages/openai/api_resources/abstract/engine_api_resource.py:153, in EngineAPIResource.create(cls, api_key, api_base, api_type, request_id, api_version, organization, **params)
#     127 @classmethod
#     128 def create(
#     129     cls,
#    (...)
#     136     **params,
#     137 ):
#     138     (
#     139         deployment_id,
#     140         engine,
#    (...)
#     150         api_key, api_base, api_type, api_version, organization, **params
#     151     )
# --> 153     response, _, api_key = requestor.request(
#     154         "post",
#     155         url,
#     156         params=params,
#     157         headers=headers,
#     158         stream=stream,
#     159         request_id=request_id,
#     160         request_timeout=request_timeout,
#     161     )
#     163     if stream:
#     164         # must be an iterator
#     165         assert not isinstance(response, OpenAIResponse)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/nlp/lib/python3.11/site-packages/openai/api_requestor.py:298, in APIRequestor.request(self, method, url, params, headers, files, stream, request_id, request_timeout)
#     277 def request(
#     278     self,
#     279     method,
#    (...)
#     286     request_timeout: Optional[Union[float, Tuple[float, float]]] = None,
#     287 ) -> Tuple[Union[OpenAIResponse, Iterator[OpenAIResponse]], bool, str]:
#     288     result = self.request_raw(
#     289         method.lower(),
#     290         url,
#    (...)
#     296         request_timeout=request_timeout,
#     297     )
# --> 298     resp, got_stream = self._interpret_response(result, stream)
#     299     return resp, got_stream, self.api_key
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/nlp/lib/python3.11/site-packages/openai/api_requestor.py:700, in APIRequestor._interpret_response(self, result, stream)
#     692     return (
#     693         self._interpret_response_line(
#     694             line, result.status_code, result.headers, stream=True
#     695         )
#     696         for line in parse_stream(result.iter_lines())
#     697     ), True
#     698 else:
#     699     return (
# --> 700         self._interpret_response_line(
#     701             result.content.decode("utf-8"),
#     702             result.status_code,
#     703             result.headers,
#     704             stream=False,
#     705         ),
#     706         False,
#     707     )
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/nlp/lib/python3.11/site-packages/openai/api_requestor.py:765, in APIRequestor._interpret_response_line(self, rbody, rcode, rheaders, stream)
#     763 stream_error = stream and "error" in resp.data
#     764 if stream_error or not 200 <= rcode < 300:
# --> 765     raise self.handle_error_response(
#     766         rbody, rcode, resp.data, rheaders, stream_error=stream_error
#     767     )
#     768 return resp
#
# RateLimitError: You exceeded your current quota, please check your plan and billing details.
